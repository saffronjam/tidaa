# %% [markdown]
# # Lab 3

# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %% [markdown]
# ## Load data

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Load month wise

# %%
# January

base_path = 'G:\My Drive\Edu\CM1001 Applied Machine Learning and Data Mining\Taxi-Data\'
# base_path = '/content/drive/MyDrive/Edu/CM1001 Applied Machine Learning and Data Mining/Taxi-Data/'

yellow_taxi = 'yellow_tripdata_2019-0{month}.csv'
green_taxi = 'green_tripdata_2019-0{month}.csv'
forhire_taxi = 'fhv_tripdata_2019-0{month}.csv'
forhire_hv_taxi = 'fhvhv_tripdata_2019-0{month}.csv'

# %%
data = {}
data_frame = pd.DataFrame()
for month_index in range(1, 2):
  path = base_path + green_taxi.format(month = month_index)

  print(path)

  col_list = ['lpep_pickup_datetime', 'lpep_dropoff_datetime', 'trip_distance', 'PULocationID', 'DOLocationID']
  data_frame = data_frame.append(pd.read_csv(path, usecols=col_list))
  data_frame.rename(columns={'tpep_pickup_datetime': 'start', 'tpep_dropoff_datetime': 'end'}, inplace=True)
  data_frame.rename(columns={'lpep_pickup_datetime': 'start', 'lpep_dropoff_datetime': 'end'}, inplace=True)

  print(data_frame)

  data_frame.start= pd.to_datetime(data_frame.start)
  data_frame.end = pd.to_datetime(data_frame.end)

  data_frame.duration = (data_frame.end-data_frame.start).astype('timedelta64[s]')



  print(data_frame)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-81cb760910df> in <module>()
#       1 data = {}
# ----> 2 data_frame = pd.DataFrame()
#       3 for month_index in range(1, 2):
#       4   path = base_path + green_taxi.format(month = month_index)
#       5
#
# NameError: name 'pd' is not defined
